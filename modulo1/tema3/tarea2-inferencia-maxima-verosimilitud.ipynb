# %% [markdown]
# # Tarea 2. Inferencia básica y máxima verosimilitud
#
# <img style="float: right; margin: 0px 0px 15px 15px;" src="https://storage.needpix.com/rsynced_images/bayesian-2889576_1280.png" width="200px" height="180px" />
#
# En esta segunda tarea, repasarás algunos ejercicios de inferencia en modelos probabilísticos básicos. Además, tendrás la oportunidad de mostrar como estimar los parámetros de una distribución normal. Finalmente explorarás cómo es el producto de dos densidades normales.
#
# Por favor, intenta ser lo más explícit@ posible, y en lo posible, apóyate de la escritura matemática con $\LaTeX$.
#
# Recuerda además que ante cualquier duda, me puedes contactar al correo esjimenezro@iteso.mx.
#
# <p style="text-align:right;"> Imagen recuperada de: https://storage.needpix.com/rsynced_images/bayesian-2889576_1280.png.</p>
#
# ___

# %% [markdown]
# ## 1.
#
# Consideramos un conjunto de datos
#
# $$
# \mathcal{D} = \{x_1, \dots, x_N\}
# $$
#
# independientes e idénticamente distribuidos, los cuales suponemos que provienen de una distribución normal $\mathcal{N}(\mu, \sigma^2)$.
#
# Muestre que los estimadores de máxima verosimilitud para los parámetros $\mu$ y $\sigma^2$ son:
#
# $$\hat{\mu}_{MLE} = \frac{1}{N} \sum_{j=1}^{N}x_j \qquad \text{y} \qquad \hat{\sigma}_{MLE}^2 = \frac{1}{N}\sum_{j=1}^{N}(x_j-\hat{\mu}_{MLE})^2.$$

# %% [markdown]
# ### Estimadores de máxima verosimilitud para $\mu$ y $\sigma^2$
#
# Consideramos un conjunto de datos
#
# $$
# \mathcal{D} = \{x_1, \dots, x_N\}
# $$
#
# independientes e idénticamente distribuidos, los cuales suponemos que provienen de una distribución normal $\mathcal{N}(\mu, \sigma^2)$.
#
# #### 1. Función de verosimilitud
#
# La función de densidad de probabilidad de una normal es:
#
# $$
# f(x|\mu, \sigma^2) = \frac{1}{\sqrt{2\pi\sigma^2}} \exp\left( -\frac{(x - \mu)^2}{2\sigma^2} \right)
# $$
#
# La función de verosimilitud es:
#
# $$
# L(\mu, \sigma^2 | \mathcal{D}) = \prod_{j=1}^{N} \frac{1}{\sqrt{2\pi\sigma^2}} \exp\left( -\frac{(x_j - \mu)^2}{2\sigma^2} \right)
# $$
#
# Tomamos el logaritmo de la función de verosimilitud:
#
# $$
# \log L(\mu, \sigma^2 | \mathcal{D}) = -\frac{N}{2} \log(2\pi\sigma^2) - \frac{1}{2\sigma^2} \sum_{j=1}^{N} (x_j - \mu)^2
# $$
#
# #### 2. Maximización con respecto a $\mu$
#
# Para encontrar el estimador de máxima verosimilitud de $\mu$, derivamos la log-verosimilitud con respecto a $\mu$ y la igualamos a cero:
#
# $$
# \frac{\partial}{\partial \mu} \log L(\mu, \sigma^2 | \mathcal{D}) = \frac{1}{\sigma^2} \sum_{j=1}^{N} (x_j - \mu) = 0
# $$
#
# Multiplicamos ambos lados por $\sigma^2$ y reorganizamos la ecuación:
#
# $$
# \sum_{j=1}^{N} (x_j - \mu) = 0 \quad \Rightarrow \quad \sum_{j=1}^{N} x_j = N\mu \quad \Rightarrow \quad \hat{\mu}_{MLE} = \frac{1}{N} \sum_{j=1}^{N}x_j
# $$
#
# #### 3. Maximización con respecto a $\sigma^2$
#
# Derivamos la log-verosimilitud con respecto a $\sigma^2$ y la igualamos a cero:
#
# $$
# \frac{\partial}{\partial \sigma^2} \log L(\mu, \sigma^2 | \mathcal{D}) = -\frac{N}{2\sigma^2} + \frac{1}{2\sigma^4} \sum_{j=1}^{N} (x_j - \mu)^2 = 0
# $$
#
# Multiplicamos por $2\sigma^4$ para despejar:
#
# $$
# -N\sigma^2 + \sum_{j=1}^{N} (x_j - \mu)^2 = 0 \quad \Rightarrow \quad \hat{\sigma}_{MLE}^2 = \frac{1}{N} \sum_{j=1}^{N} (x_j - \hat{\mu}_{MLE})^2
# $$
#
# #### 4. Conclusión
#
# Los estimadores de máxima verosimilitud para $\mu$ y $\sigma^2$ son:
# <font color="#FF5733">
# $$
# \hat{\mu}_{MLE} = \frac{1}{N} \sum_{j=1}^{N}x_j \qquad \text{y} \qquad \hat{\sigma}_{MLE}^2 = \frac{1}{N} \sum_{j=1}^{N} (x_j - \hat{\mu}_{MLE})^2
# $$
# </font>
#
# ___

# %% [markdown]
# ## 2.
#
# Consideramos un conjunto de datos
#
# $$
# \mathcal{D} = \{x_1, \dots, x_N\}
# $$
#
# independientes e idénticamente distribuidos, los cuales suponemos que provienen de una distribución Gamma, con la siguiente pdf
#
# $$
# p(x | a) = \frac{a^5}{4!} x^4 e^{-ax}
# $$
#
# Encuentre el estimador de máxima verosimilitud para $a$.

# %% [markdown]
# ### Estimador de máxima verosimilitud para $a$ en una distribución Gamma
#
# Consideramos un conjunto de datos
#
# $$
# \mathcal{D} = \{x_1, \dots, x_N\}
# $$
#
# independientes e idénticamente distribuidos, los cuales suponemos que provienen de una distribución Gamma, con la siguiente función de densidad de probabilidad:
#
# $$
# p(x | a) = \frac{a^5}{4!} x^4 e^{-ax}
# $$
#
# #### 1. Función de verosimilitud
#
# La función de verosimilitud conjunta para los \(N\) datos es:
#
# $$
# L(a | \mathcal{D}) = \prod_{j=1}^{N} p(x_j | a) = \prod_{j=1}^{N} \frac{a^5}{4!} x_j^4 e^{-a x_j}
# $$
#
# ##### Simplificando:
#
# $$
# L(a | \mathcal{D}) = \left( \frac{a^5}{4!} \right)^N \prod_{j=1}^{N} x_j^4 e^{-a \sum_{j=1}^{N} x_j}
# $$
#
# ##### Log-verosimilitud
#
# Es más fácil trabajar con la log-verosimilitud:
#
# $$
# \log L(a | \mathcal{D}) = N \log \left( \frac{a^5}{4!} \right) + \sum_{j=1}^{N} \log(x_j^4) - a \sum_{j=1}^{N} x_j
# $$
#
# ##### Simplificado:
#
# $$
# \log L(a | \mathcal{D}) = N \left( 5 \log(a) - \log(4!) \right) + 4 \sum_{j=1}^{N} \log(x_j) - a \sum_{j=1}^{N} x_j
# $$
#
# ##### Derivada de la log-verosimilitud con respecto a \(a\)
#
# Para encontrar el estimador de máxima verosimilitud, derivamos la log-verosimilitud con respecto a \(a\) y la igualamos a cero:
#
# $$
# \frac{\partial}{\partial a} \log L(a | \mathcal{D}) = N \frac{5}{a} - \sum_{j=1}^{N} x_j = 0
# $$
#
# Despejamos \(a\):
#
# $$
# \hat{a}_{MLE} = \frac{5N}{\sum_{j=1}^{N} x_j}
# $$
#
# #### 3. Conclusión
#
# El estimador para $a$ es:
# <font color="#FF5733">
# $$
# \hat{a}_{MLE} = \frac{5N}{\sum_{j=1}^{N} x_j}
# $$
# <font>

# %% [markdown]
# <script>
#   $(document).ready(function(){
#     $('div.prompt').hide();
#     $('div.back-to-top').hide();
#     $('nav#menubar').hide();
#     $('.breadcrumb').hide();
#     $('.hidden-print').hide();
#   });
# </script>
#
# <footer id="attribution" style="float:right; color:#808080; background:#fff;">
# Created with Jupyter by Esteban Jiménez Rodríguez.
# </footer>
